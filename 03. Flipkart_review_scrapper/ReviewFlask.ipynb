# %% [markdown]
# #### Task
# 1. Task - go to a website
# 1. Task - search for respective product
# 1. Task - locate review part
# 1. Task - scrap all the data in the local system

# %%
# !pip install flask_cors

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + 'moto'
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=moto'

# %%
uClient = uReq(flipkart_url)
uClient

# %%
flipkartPage = uClient.read()
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
uClient.close()

# %%
flipkart_html = bs(flipkartPage,"html.parser")
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigboxes = flipkart_html.findAll("div",{"class":"_1AtVbE col-12-12"})
bigboxes
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=moto&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div><div><a class="_2SqgSY" href="/mobiles-accessories/mobiles/pr?sid=tyy,4io&amp;q=moto&amp;otracker=categorytree" title="Mobiles">Mobiles</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class=""
# ...

# %%
len(bigboxes)
# Out:
# 29

# %%
bigboxes[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=moto&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div><div><a class="_2SqgSY" href="/mobiles-accessories/mobiles/pr?sid=tyy,4io&amp;q=moto&amp;otracker=categorytree" title="Mobiles">Mobiles</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" 
# ...

# %%
box = bigboxes[0]
box
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=moto&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div><div><a class="_2SqgSY" href="/mobiles-accessories/mobiles/pr?sid=tyy,4io&amp;q=moto&amp;otracker=categorytree" title="Mobiles">Mobiles</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" 
# ...

# %%
box.div
# Out:
# <div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=moto&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div><div><a class="_2SqgSY" href="/mobiles-accessories/mobiles/pr?sid=tyy,4io&amp;q=moto&amp;otracker=categorytree" title="Mobiles">Mobiles</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.
# ...

# %%
box.div.div
# Out:
# <div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div>

# %%
box.div.div.div.a['hreaf']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 box.div.div.div.a['hreaf']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
del bigboxes[0:3]
box = bigboxes[0]
box
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBG2EMWUMUFGSZE" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/motorola-e40-carbon-gray-64-gb/p/itm0ca635007c9e2?pid=MOBG2EMWUMUFGSZE&amp;lid=LSTMOBG2EMWUMUFGSZE5BRN80&amp;marketplace=FLIPKART&amp;q=moto&amp;store=search.flipkart.com&amp;spotlightTagId=BestsellerId_search.flipkart.com&amp;srno=s_1_3&amp;otracker=search&amp;fm=organic&amp;iid=d9d694ad-2965-4030-85ce-f9f62b40655c.MOBG2EMWUMUFGSZE.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=6db8b8hd3k0000001673610541587&amp;qH=fc6b46fe888f1cbe" rel="noopener noreferrer" target="_blank"><div></div><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="MOTOROLA e40 (Carbon Gray, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/l1l1rww0/mobile/v/7/n/-original-imagd48zkjwujxzz.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A
# ...

# %%
box.div.div.a
# Out:
# <a class="_1fQZEK" href="/motorola-e40-carbon-gray-64-gb/p/itm0ca635007c9e2?pid=MOBG2EMWUMUFGSZE&amp;lid=LSTMOBG2EMWUMUFGSZE5BRN80&amp;marketplace=FLIPKART&amp;q=moto&amp;store=search.flipkart.com&amp;spotlightTagId=BestsellerId_search.flipkart.com&amp;srno=s_1_3&amp;otracker=search&amp;fm=organic&amp;iid=d9d694ad-2965-4030-85ce-f9f62b40655c.MOBG2EMWUMUFGSZE.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=6db8b8hd3k0000001673610541587&amp;qH=fc6b46fe888f1cbe" rel="noopener noreferrer" target="_blank"><div></div><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="MOTOROLA e40 (Carbon Gray, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/l1l1rww0/mobile/v/7/n/-original-imagd48zkjwujxzz.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><l
# ...

# %%
box.div.div.a['href'] # now we have extracted the URL
# Out:
# '/motorola-e40-carbon-gray-64-gb/p/itm0ca635007c9e2?pid=MOBG2EMWUMUFGSZE&lid=LSTMOBG2EMWUMUFGSZE5BRN80&marketplace=FLIPKART&q=moto&store=search.flipkart.com&spotlightTagId=BestsellerId_search.flipkart.com&srno=s_1_3&otracker=search&fm=organic&iid=d9d694ad-2965-4030-85ce-f9f62b40655c.MOBG2EMWUMUFGSZE.SEARCH&ppt=None&ppn=None&ssid=6db8b8hd3k0000001673610541587&qH=fc6b46fe888f1cbe'

# %%
product_link = "https://www.flipkart.com/search?q=" + box.div.div.a['href']
product_link
# Out:
# 'https://www.flipkart.com/search?q=/motorola-e40-carbon-gray-64-gb/p/itm0ca635007c9e2?pid=MOBG2EMWUMUFGSZE&lid=LSTMOBG2EMWUMUFGSZE5BRN80&marketplace=FLIPKART&q=moto&store=search.flipkart.com&spotlightTagId=BestsellerId_search.flipkart.com&srno=s_1_3&otracker=search&fm=organic&iid=d9d694ad-2965-4030-85ce-f9f62b40655c.MOBG2EMWUMUFGSZE.SEARCH&ppt=None&ppn=None&ssid=6db8b8hd3k0000001673610541587&qH=fc6b46fe888f1cbe'

# %%
prodRes = requests.get(product_link)
prodRes
# Out:
# <Response [200]>

# %%
prodRes.encoding='utf-8'

# %%
prod_html = bs(prodRes.text, "html.parser")
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})
commentboxes
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Delightful</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Best purchase with a good price.<br>Camera quality is awesome with a great battery backup and that's the reason for love to Moto.<br><br/>This is a genuine review and one can get this mobile with out any doubt.</br></br></div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202202/blobio-imr-202202_b3909e4ff6964bff8edc102c38666c1e.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Sirisha Gattem</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/sv
# ...

# %%
len(commentboxes)
# Out:
# 11

# %%
commentboxes[0].div
# Out:
# <div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Delightful</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Best purchase with a good price.<br>Camera quality is awesome with a great battery backup and that's the reason for love to Moto.<br><br/>This is a genuine review and one can get this mobile with out any doubt.</br></br></div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202202/blobio-imr-202202_b3909e4ff6964bff8edc102c38666c1e.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Sirisha Gattem</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" c
# ...

# %%
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})
# Out:
# [<p class="_2sc7ZR _2V5EHH">Sirisha Gattem</p>]

# %%
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0]
# Out:
# <p class="_2sc7ZR _2V5EHH">Sirisha Gattem</p>

# %%
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
# Out:
# 'Sirisha Gattem'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text)
# Out:
# Sirisha Gattem
# Prashant  Koli
# Flipkart Customer
# Sharan  R
# Saurav Kumar
# Manish  Kalia
# AMAR KUMAR
# Flipkart Customer
# Vinod Kumar
# Ajay Krishna Shet

# %%
commentboxes[0].div
# Out:
# <div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Delightful</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Best purchase with a good price.<br>Camera quality is awesome with a great battery backup and that's the reason for love to Moto.<br><br/>This is a genuine review and one can get this mobile with out any doubt.</br></br></div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202202/blobio-imr-202202_b3909e4ff6964bff8edc102c38666c1e.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Sirisha Gattem</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" c
# ...

# %%
commentboxes[0].div.div.div.div.text
# Out:
# '4'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text)
    print(commentboxes[i].div.div.div.div.text)
    print(commentboxes[i].div.div.div.p.text)
    # print(commentboxes[i].div.div.find_all('div', {'class': ''}))
    comtag = commentboxes[i].div.div.find_all('div', {'class': ''})
    print(comtag[0].div.text,'\n ------------------------------------------------------------------------------------------------------')
# Out:
# Sirisha Gattem
# 4
# Delightful
# Best purchase with a good price.Camera quality is awesome with a great battery backup and that's the reason for love to Moto.This is a genuine review and one can get this mobile with out any doubt.
#  ------------------------------------------------------------------------------------------------------
# Prashant  Koli
# 5
# Highly recommended
# Very good 👍 phoneLatest processor T700 from unisoc performance is goodCamera is clear and brighter, battery performance also good, and the most important thing in this phone is stock android os, it doesn't have adware and bloatware, it's original android.
#  ------------------------------------------------------------------------------------------------------
# Flipkart Customer
# 5
# Great product
# ...
